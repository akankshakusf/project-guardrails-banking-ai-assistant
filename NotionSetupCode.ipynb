# %%
import os
from dotenv import load_dotenv

# Load AWS credentials from .env file
load_dotenv()

os.environ["AWS_ACCESS_KEY_ID"] = os.getenv("AWS_ACCESS_KEY_ID")
os.environ["AWS_SECRET_ACCESS_KEY"] = os.getenv("AWS_SECRET_ACCESS_KEY")
os.environ["AWS_REGION"] = os.getenv("AWS_REGION", "us-east-1")

# %%
# !uv pip install langchain langchain-community boto3
# !uv pip install langchain-aws
# !uv pip install notion-client
# Out:
# Audited 1 package in 278ms

# %%
import boto3
from langchain_aws.embeddings import BedrockEmbeddings

# Initialize the client
client = boto3.client("bedrock-runtime", region_name="us-east-1")
# Use Titan Embeddings V2
titan_embedder = BedrockEmbeddings(
    client=client,
    model_id="amazon.titan-embed-text-v2:0"
)

# %%
## dry run 
sample_text = "Airport lounge access is available with Amex Platinum."
embedding = titan_embedder.embed_query(sample_text)

print(f"Embedding size: {len(embedding)}")
print(f"First 5 dimensions: {embedding[:5]}")
# Out:
# Embedding size: 1024
# First 5 dimensions: [-0.04292689636349678, 0.06853839755058289, 0.019514024257659912, -0.007966389879584312, 0.0385114811360836]

# %% [markdown]
# ### Notion Text Handling

# %% [markdown]
# - notion_list_dbs.py

# %%
import os
from notion_client import Client
from dotenv import load_dotenv

load_dotenv()
notion = Client(auth=os.getenv("NOTION_API_KEY"))

# Search for databases
response = notion.search(filter={"property": "object", "value": "database"})

for result in response["results"]:
    print("Title:", result["title"][0]["plain_text"] if result["title"] else "No title")
    print("ID:", result["id"])
    print("---")
# Out:
# Title: Topics
# ID: 2394ba18-200f-81de-8a3e-ee605002d26a
# ---

# %% [markdown]
# - notion_fetch_rows.py

# %%
import os
from notion_client import Client
from dotenv import load_dotenv

load_dotenv()
notion = Client(auth=os.getenv("NOTION_API_KEY"))

database_id = "2394ba18-200f-81de-8a3e-ee605002d26a"

# Query database rows (pages)
response = notion.databases.query(database_id=database_id)

for page in response["results"]:
    props = page["properties"]
    title = props["Name"]["title"][0]["plain_text"] if props["Name"]["title"] else "Untitled"
    print("Title:", title)

    # You can extract more fields depending on your DB schema
    for key, val in props.items():
        if val["type"] == "rich_text":
            content = val["rich_text"][0]["plain_text"] if val["rich_text"] else ""
            print(f"{key}: {content}")
    print("---")
# Out:
# Title: 🛒 Consumer Categories
# Description: Description
# ---
# Title: Travel-Related Rewards Categories
# Description: This page outlines the travel-related categories eligible for additional rewards on your Amex Card, including airfare, hotels, transit, and car rentals.
# ---
# Title: Amex Rewards Information
# Description: Here you can find detailed information about Amex Rewards, including points system, redemption options, bonus categories, and expiration rules.
# ---
# Title: Business-Related Rewards Categories
# Description: This page outlines business-specific purchase categories that are eligible for additional rewards on your Amex Card, including Amazon Business, shipping, software, office supplies, and wireless providers.
# ---

# %% [markdown]
# notion_get_blocks.py

# %% [markdown]
# - Tile content pull code

# %%
https://www.notion.so/Amex-Help-Center-Knowledge-Base-2394ba18200f80c3ba0ed88f417c09d7?source=copy_link#2394ba18200f802ab396e79e36e9f40d
https://www.notion.so/Amex-Help-Center-Knowledge-Base-2394ba18200f80c3ba0ed88f417c09d7?source=copy_link#23a4ba18200f80f69e00ed436fc647c6
https://www.notion.so/Amex-Help-Center-Knowledge-Base-2394ba18200f80c3ba0ed88f417c09d7?source=copy_link#23a4ba18200f801786d2de2f26bb4a9c
https://www.notion.so/Amex-Help-Center-Knowledge-Base-2394ba18200f80c3ba0ed88f417c09d7?source=copy_link#23a4ba18200f8044b127e83767cb5ef5

# %% [markdown]
# - WORKING FOR FAQs

# %%
def extract_block_text(block):
    block_type = block["type"]
    rich_parts = block.get(block_type, {}).get("rich_text", [])
    return "".join(part.get("plain_text", "") for part in rich_parts)

def extract_children_recursive(block_id, notion):
    """Recursively fetches children (like nested answers)."""
    children = []
    response = notion.blocks.children.list(block_id)
    for child in response.get("results", []):
        text = extract_block_text(child)
        if text:
            if child["type"] == "bulleted_list_item":
                children.append(f"- {text}")
            else:
                children.append(text)
        # Recurse further if this child has its own children
        if child.get("has_children"):
            children.extend(extract_children_recursive(child["id"], notion))
    return children

def convert_page_to_doc_full(page_title, page_id, notion):
    content_lines = []

    def walk_blocks(blocks):
        for block in blocks:
            block_type = block["type"]
            text = extract_block_text(block)

            if block_type.startswith("heading") and text:
                content_lines.append(f"\n## {text}")
            elif block_type == "paragraph" and text:
                content_lines.append(text)
            elif block_type == "callout" and text:
                content_lines.append(f"💬 {text}")
            elif block_type == "bulleted_list_item" and text:
                content_lines.append(f"- {text}")
            elif block_type == "toggle" and text:
                content_lines.append(f"\n### ❓ {text}")
                # Pull its children recursively
                children = extract_children_recursive(block["id"], notion)
                content_lines.extend(children)

            # Recurse into all child blocks
            if block.get("has_children") and block_type != "toggle":
                sub_blocks = notion.blocks.children.list(block["id"])["results"]
                walk_blocks(sub_blocks)

    # Start walking from root page
    root_blocks = notion.blocks.children.list(page_id)["results"]
    walk_blocks(root_blocks)

    full_text = "\n".join(content_lines).strip()
    return {
        "page_content": full_text,
        "metadata": {"source": page_title}
    }

# %%
from assistant.core.notion_amex_faqs import convert_page_to_doc_full
from notion_client import Client
import os

notion = Client(auth=os.getenv("NOTION_API_KEY"))
page_id = "2394ba18-200f-80c3-ba0e-d88f417c09d7"
page_title = "Amex Knowledge Base"

doc = convert_page_to_doc_full(page_title, page_id, notion)

# Preview the dry run
print("🔍 FULL DRY RUN PREVIEW:\n")
for i, line in enumerate(doc["page_content"].splitlines(), 1):
    print(f"{i:02}. {line}")
# Out:
# 🔍 FULL DRY RUN PREVIEW:
#
# 01. ## Rewards Frequently Asked Questions
# 02.
# 03. ##  What purchases are eligible to earn rewards?
# 04. Eligible purchases include goods and services minus returns and credits.
# 05. They do not include:
# 06. - Fees or interest charges
# 07. - Balance transfers or cash advances
# 08. - Peer-to-peer payments
# 09. - Gift cards or traveler’s checks
# 10. - Prepaid card reloads
# 11. - Cash equivalent purchases
# 12.
# 13. ## Where can I see my purchases that qualified for additional rewards?
# 14.
# 15. You can view them under Bonus Rewards Detail in your Amex online account.
# 16.
# 17. ## How do you define a purchase made in the United States?
# 18. A purchase is considered U.S.-based if the merchant is located and registered in the U.S. Note: Some online/mobile purchases might be processed internationally.
# 19.
# 20. ## Are purchases made outside the United States eligible for additional rewards?
# 21. It depends on your card’s terms.
# 22. Check your Cardmember Agreement or Membership Rewards® Terms.
# 23.
# 24. ## How do I find out if my card has categories with additional rewards?
# 25. You can check:
# 26. - Your card’s product page
# 27. - Your Amex online account
# 28. - Or contact support for details
# 29. Bonus categories often include groceries, travel, dining, and more.
# 30.
# 31. ##  What determines the category a merchant falls under?
# 32. Amex uses a Merchant Category Code (MCC) to classify each business.
# 33.
# 34. ##  Can I miss out on bonus rewards even if my purchase is in an eligible category?
# 35. Yes, you usually earn rewards with these payment methods.
# 36. But it may vary — always double-check your card’s terms.
# 37.
# 38. ## Travel Rewards Frequently Asked Questions
# 39.
# 40. ## ✈️ Airfare – Frequently Asked Questions
# 41.
# 42. ## Do I earn additional rewards when I book airfare through American Express Travel?
# 43. Yes, you will earn additional rewards when you book airfare with American Express Travel — but not if it's part of a vacation package.
# 44.
# 45. ## Are there times I can earn additional rewards when booking through a third party?
# 46. Yes. Some purchases with third parties (like Expedia or Orbitz) may be eligible if the airline charges your card directly.
# 47.
# 48. ## What is considered a third party in the travel category?
# 49. A business that books or purchases travel on your behalf — like an online travel agent or traditional travel agency.
# 50.
# 51. ##  How do I earn additional rewards on airfare purchases?
# 52. Book a scheduled flight on a passenger airline, and make the purchase directly with the airline.
# 53.
# 54. ##  I think I should’ve earned additional rewards. What should I do?
# 55. Call the number on the back of your card to request a review of your transaction.
# 56.
# 57. ## 🏨 Hotels – Frequently Asked Questions
# 58.
# 59. ## How do I earn additional rewards for a hotel stay?
# 60. Book directly with the hotel. You may prepay or pay at check-in/check-out — both are eligible if paid to the hotel itself.
# 61.
# 62. ## Will I receive additional rewards on all hotel stays?
# 63.
# 64. Not always. Hotel bookings through third parties or as part of vacation packages are usually not eligible. Timeshares, banquets, and events are also excluded.
# 65.
# 66. ## What if I book my hotel as part of a vacation package?
# 67.
# 68. Hotel rooms bundled into vacation packages do not qualify for additional rewards.
# 69.
# 70. ##  I think I should’ve earned additional rewards. What should I do?
# 71. Contact Amex customer service to review the transaction using the number on the back of your card
# 72.
# 73. ## 🚗 Select Car Rentals – Frequently Asked Questions
# 74.
# 75. ## Which car rental companies are eligible?
# 76. Alamo, Avis, Budget, Dollar, Enterprise, E-Z, Fox, Hertz, National, Payless, Sixt, and Thrifty.
# 77.
# 78. ##  Will I earn rewards on international car rentals?
# 79. Yes — if you book directly with one of the select car rental companies listed above, even internationally.
# 80.
# 81. ## If I book a vacation package through a rental company, do I earn rewards?
# 82. No. Vacation packages do not qualify, even if booked with a participating rental company.
# 83.
# 84. ## What if I rent a car as part of a vacation package?
# 85. That rental is ineligible because it's not a direct booking with the rental company.
# 86.
# 87. ## Select Computer Hardware, Software, & Cloud Computing – FAQs
# 88.
# 89. ## Which providers are included in your select list?
# 90. Apple, CDW, Dell, HP, IBM, Intuit, Lenovo, Microsoft, Newegg, Oracle, Rackspace, Sage Software, Salesforce.com, Symantec, and Tiger Direct.
# 91.
# 92. ## Can a purchase earn rewards in multiple categories?
# 93. Yes. You may earn additional points in multiple categories from a single purchase. That purchase will count against category-specific caps set by your card. Purchases above the cap will earn 1 point per dollar.
# 94.
# 95. ## How do I earn additional rewards in this category?
# 96. You must make a purchase directly from a listed provider in the U.S. using your eligible Amex card.
# 97.
# 98. ##  I think I should’ve earned additional rewards. What should I do?
# 99. Call the number on the back of your card to request a transaction review.
# 100.
# 101. ## U.S. Advertising in Select Media – FAQs
# 102.
# 103. ##  How do I earn additional rewards on advertising purchases?
# 104.
# 105. You must purchase online, television, or radio advertising in the U.S. directly from a media provider to promote your business.
# 106.
# 107.
# 108. ## U.S. Office Supply Stores – FAQs
# 109.
# 110. ## How do you define an office supply store?
# 111. Stores that primarily sell business-related office supplies, including paper, printers, desks, and filing cabinets (e.g., Staples, Office Depot).
# 112.
# 113. ## How do I earn additional rewards at office supply stores?
# 114. Make purchases directly at U.S. office supply stores.
# 115.
# 116. ## U.S. Shipping – FAQs
# 117.
# 118. ## Will I earn rewards for international shipping?
# 119.
# 120. Yes, if the purchase is made from a U.S.-based courier or freight shipper, like UPS, FedEx, or USPS.
# 121.
# 122. ## How do I earn additional rewards for shipping or freight?
# 123.
# 124. Simply make your purchase with a U.S.-based shipping provider, regardless of whether the item is shipped domestically or internationally.
# 125.
# 126. ## U.S. Gas Stations FAQs
# 127.
# 128. ## How do you define a gas station where I earn additional rewards?
# 129. A gas station is a merchant whose primary business is selling gasoline to consumers. While they may sell convenience items, their main business must be gasoline. Superstores, supermarkets, and warehouse clubs are excluded.
# 130.
# 131. ## I think I should have earned additional rewards on a purchase. What should I do?
# 132.
# 133. Please call the number on the back of your Card for any questions regarding missing rewards.
# 134.
# 135. ## U.S. Online Retail Purchases FAQs
# 136.
# 137. ## How do I earn additional rewards on online retail purchases?
# 138.
# 139. Purchase must be made online via a U.S. retail merchant (website or app) that sells physical goods directly to consumers.
# 140.
# 141. ## What isn’t included in this category?
# 142.
# 143. Restaurants, supermarkets, gas stations, auto dealers, travel, entertainment, services, and purchases made by phone/mail or via “Buy Now Pay Later” programs.
# 144.
# 145. ## Do brick-and-mortar stores disqualify a merchant?
# 146. No. If the merchant has an online store and the purchase is made online, it is eligible.
# 147.
# 148. ## Are online purchases at U.S. supermarkets included?
# 149.
# 150. No. Supermarkets (including online grocery orders) are a separate rewards category.
# 151.
# 152.
# 153. ## Are orders picked up in store eligible?
# 154.
# 155. Yes, if paid online and the transaction is classified by the merchant as an internet purchase.
# 156.
# 157. ## U.S. Restaurants FAQs
# 158.
# 159. ## I think I should have earned additional rewards. What should I do?
# 160.
# 161. Please call the number on the back of your Card.
# 162.
# 163. ## Are fast food restaurants included?
# 164.
# 165. Yes, they are part of the U.S. restaurant category.
# 166.
# 167. ## When might I not earn rewards at a restaurant?
# 168.
# 169. If the merchant code does not reflect a restaurant (e.g., inside a hotel or food court), it may not qualify.
# 170.
# 171. ## How do I earn rewards for restaurant purchases?
# 172.
# 173. The restaurant must be located in the U.S.. U.S.-owned restaurants located abroad (e.g., Hard Rock Café in Paris) do not qualify.
# 174.
# 175. ## Global Restaurants FAQs
# 176.
# 177. ## I think I should have earned additional rewards. What should I do?
# 178.
# 179. Call the number on the back of your Card for support.
# 180.
# 181. ## Are fast food restaurants included globally?
# 182. Yes, fast food is included.
# 183.
# 184. ## When are rewards not earned?
# 185. If a restaurant is inside another venue (hotel, casino, etc.) or not classified as a restaurant by the merchant’s code.

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.vectorstores import FAISS

splitter = RecursiveCharacterTextSplitter(
    chunk_size=500,
    chunk_overlap=100
)

chunks = splitter.create_documents([doc["page_content"]])

# Then embed these chunks into FAISS
vectorstore = FAISS.from_documents(chunks, titan_embedder)
vectorstore.save_local("vectorstore/notion_amex_faqs")

# %%
# Dry run preview
# Step 1: Load the FAISS vector store
vectorstore = FAISS.load_local(
    "vectorstore/notion_amex_faqs",
    titan_embedder,
    allow_dangerous_deserialization=True
)

# Step 2: Define a test query
query = "How do I earn rewards for booking flights with Amex?"

# Step 3: Perform a similarity search
results = vectorstore.similarity_search(query, k=3)

# Step 4: Preview top matches
print(f"🔍 Query: {query}\n")
for i, doc in enumerate(results, 1):
    print(f"--- Match {i} ---\n{doc.page_content}\n")
# Out:
# 🔍 Query: How do I earn rewards for booking flights with Amex?
#
# --- Match 1 ---
# ## Travel Rewards Frequently Asked Questions
#
# ## ✈️ Airfare – Frequently Asked Questions
#
# ## Do I earn additional rewards when I book airfare through American Express Travel?
# Yes, you will earn additional rewards when you book airfare with American Express Travel — but not if it's part of a vacation package.
#
# --- Match 2 ---
# ##  How do I earn additional rewards on airfare purchases?
# Book a scheduled flight on a passenger airline, and make the purchase directly with the airline.
#
# ##  I think I should’ve earned additional rewards. What should I do?
# Call the number on the back of your card to request a review of your transaction.
#
# ## 🏨 Hotels – Frequently Asked Questions
#
# --- Match 3 ---
# ## What if I book my hotel as part of a vacation package?
#
# Hotel rooms bundled into vacation packages do not qualify for additional rewards.
#
# ##  I think I should’ve earned additional rewards. What should I do?
# Contact Amex customer service to review the transaction using the number on the back of your card
#
# ## 🚗 Select Car Rentals – Frequently Asked Questions
